# %% [markdown]
# ## 1.0 Collecting the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf
import joblib

# %%
now = datetime.now()
start = datetime(now.year - 10, now.month, now.day)
end = now
ticker = 'AMZN'
df = yf.download(ticker, start, end)
df
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AMZN        AMZN        AMZN        AMZN      AMZN
# Date
# 2015-05-18   21.261999   21.363501   21.073000   21.299999  47804000
# 2015-05-19   21.085501   21.412001   21.031500   21.243500  49284000
# 2015-05-20   21.193001   21.355000   20.917999   21.030001  43924000
# 2015-05-21   21.581499   21.844999   21.400000   21.400000  82428000
# 2015-05-22   21.381500   21.622000   21.380501   21.577499  40412000
# ...                ...         ...         ...         ...       ...
# 2025-05-12  208.639999  211.660004  205.750000  210.710007  75205000
# 2025-05-13  211.369995  214.839996  210.100006  211.080002  56193700
# 2025-05-14  210.250000  211.929993  208.850006  211.449997  38492100
# 2025-05-15  205.169998  206.880005  202.669998  206.449997  64347300
# 2025-05-16  205.589996  206.850006  204.369995  206.850006  43072700
#
# [2516 rows x 5 columns]

# %% [markdown]
# ## 2.0 Data Exploration

# %%
df.shape
# Out:
# (2516, 5)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isna().sum()
# Out:
# Price   Ticker
# Close   AMZN      0
# High    AMZN      0
# Low     AMZN      0
# Open    AMZN      0
# Volume  AMZN      0
# dtype: int64

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AMZN        AMZN        AMZN        AMZN      AMZN
# Date
# 2025-05-12  208.639999  211.660004  205.750000  210.710007  75205000
# 2025-05-13  211.369995  214.839996  210.100006  211.080002  56193700
# 2025-05-14  210.250000  211.929993  208.850006  211.449997  38492100
# 2025-05-15  205.169998  206.880005  202.669998  206.449997  64347300
# 2025-05-16  205.589996  206.850006  204.369995  206.850006  43072700

# %%
df.dtypes
# Out:
# Price   Ticker
# Close   AMZN      float64
# High    AMZN      float64
# Low     AMZN      float64
# Open    AMZN      float64
# Volume  AMZN        int64
# dtype: object

# %%
df = df.reset_index()
df
# Out:
# Price        Date       Close        High         Low        Open    Volume
# Ticker                   AMZN        AMZN        AMZN        AMZN      AMZN
# 0      2015-05-18   21.261999   21.363501   21.073000   21.299999  47804000
# 1      2015-05-19   21.085501   21.412001   21.031500   21.243500  49284000
# 2      2015-05-20   21.193001   21.355000   20.917999   21.030001  43924000
# 3      2015-05-21   21.581499   21.844999   21.400000   21.400000  82428000
# 4      2015-05-22   21.381500   21.622000   21.380501   21.577499  40412000
# ...           ...         ...         ...         ...         ...       ...
# 2511   2025-05-12  208.639999  211.660004  205.750000  210.710007  75205000
# 2512   2025-05-13  211.369995  214.839996  210.100006  211.080002  56193700
# 2513   2025-05-14  210.250000  211.929993  208.850006  211.449997  38492100
# 2514   2025-05-15  205.169998  206.880005  202.669998  206.449997  64347300
# 2515   2025-05-16  205.589996  206.850006  204.369995  206.850006  43072700
#
# [2516 rows x 6 columns]

# %%
plt.figure(figsize=(12, 5))
plt.title(ticker)
plt.ylabel('Close Price')
plt.xlabel('Days')
plt.plot(df.Close)

# %% [markdown]
# ## 3.0 Feature Engineering

# %% [markdown]
# ### Calculation 100 moving average

# %%
df['100 MA'] = df.Close.rolling(100).mean()
df
# Out:
# Price        Date       Close        High         Low        Open    Volume  \
# Ticker                   AMZN        AMZN        AMZN        AMZN      AMZN
# 0      2015-05-18   21.261999   21.363501   21.073000   21.299999  47804000
# 1      2015-05-19   21.085501   21.412001   21.031500   21.243500  49284000
# 2      2015-05-20   21.193001   21.355000   20.917999   21.030001  43924000
# 3      2015-05-21   21.581499   21.844999   21.400000   21.400000  82428000
# 4      2015-05-22   21.381500   21.622000   21.380501   21.577499  40412000
# ...           ...         ...         ...         ...         ...       ...
# 2511   2025-05-12  208.639999  211.660004  205.750000  210.710007  75205000
# 2512   2025-05-13  211.369995  214.839996  210.100006  211.080002  56193700
# 2513   2025-05-14  210.250000  211.929993  208.850006  211.449997  38492100
# 2514   2025-05-15  205.169998  206.880005  202.669998  206.449997  64347300
# 2515   2025-05-16  205.589996  206.850006  204.369995  206.850006  43072700
#
# Price     100 MA
# Ticker
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2511    208.3807
# 2512    208.1651
# 2513    207.9561
# 2514    207.8026
# 2515    207.6256
#
# [2516 rows x 7 columns]

# %%
plt.figure(figsize = (12, 5))
plt.plot(df.Close, 'b', label='Closing Price')
plt.plot(df['100 MA'], 'r', label = '100 MA')
plt.title(f"100 Days moving average of {ticker}")
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()

# %% [markdown]
# ### Calculating 200 days moving average

# %%
df['200 MA'] = df.Close.rolling(200).mean()
df
# Out:
# Price        Date       Close        High         Low        Open    Volume  \
# Ticker                   AMZN        AMZN        AMZN        AMZN      AMZN
# 0      2015-05-18   21.261999   21.363501   21.073000   21.299999  47804000
# 1      2015-05-19   21.085501   21.412001   21.031500   21.243500  49284000
# 2      2015-05-20   21.193001   21.355000   20.917999   21.030001  43924000
# 3      2015-05-21   21.581499   21.844999   21.400000   21.400000  82428000
# 4      2015-05-22   21.381500   21.622000   21.380501   21.577499  40412000
# ...           ...         ...         ...         ...         ...       ...
# 2511   2025-05-12  208.639999  211.660004  205.750000  210.710007  75205000
# 2512   2025-05-13  211.369995  214.839996  210.100006  211.080002  56193700
# 2513   2025-05-14  210.250000  211.929993  208.850006  211.449997  38492100
# 2514   2025-05-15  205.169998  206.880005  202.669998  206.449997  64347300
# 2515   2025-05-16  205.589996  206.850006  204.369995  206.850006  43072700
#
# Price     100 MA     200 MA
# Ticker
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 2511    208.3807  199.28635
# 2512    208.1651  199.44395
# 2513    207.9561  199.58270
# 2514    207.8026  199.69255
# 2515    207.6256  199.81195
#
# [2516 rows x 8 columns]

# %%
plt.figure(figsize = (12, 5))
plt.plot(df.Close, 'b', label='Closing Price')
plt.plot(df['100 MA'], 'r', label='100 MA')
plt.plot(df['200 MA'], 'g', label='200 MA')
plt.title(f" Closing Price, 100 days and 200 days moving average of {ticker}")
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()

# %% [markdown]
# ### Calculating percentage changed for the closing prices

# %%
df['Percentage Changed'] = df.Close.pct_change()
df[['Close', 'Percentage Changed']]
# Out:
# Price        Close Percentage Changed
# Ticker        AMZN
# 0        21.261999                NaN
# 1        21.085501          -0.008301
# 2        21.193001           0.005098
# 3        21.581499           0.018331
# 4        21.381500          -0.009267
# ...            ...                ...
# 2511    208.639999           0.080700
# 2512    211.369995           0.013085
# 2513    210.250000          -0.005299
# 2514    205.169998          -0.024162
# 2515    205.589996           0.002047
#
# [2516 rows x 2 columns]

# %%
plt.figure(figsize=(12, 5))
plt.xlabel('Days')
plt.title(f'Percentage change of closing price for {ticker}')
plt.ylabel('Percentage Change')
plt.plot(df['Percentage Changed'])

# %% [markdown]
# ## 4.0 Data Preprocessing

# %% [markdown]
# ### Splitting data into 3: train, validation, test data

# %%
from sklearn.model_selection import train_test_split

# %%
df_fulltrain, df_test = train_test_split(df, test_size = 0.2, shuffle = False)
df_train, df_val = train_test_split(df_fulltrain, test_size = 0.2 * 100/80, shuffle=False)

# %%
len(df_train) + len(df_val) + len(df_test) == len(df)
# Out:
# True

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
data_train = df_train.Close
data_train_arr = scaler.fit_transform(data_train)
data_train_arr
# Out:
# array([[1.13513297e-03],
#        [0.00000000e+00],
#        [6.91376646e-04],
#        ...,
#        [9.01104275e-01],
#        [8.77960890e-01],
#        [8.81025464e-01]])

# %% [markdown]
# ## 5.0 Sequence Creation

# %%
X_train, y_train  = [], []
seq_num = 100
for i in range(seq_num, len(data_train_arr)):
    X_train.append(data_train_arr[i-100 : i])
    y_train.append(data_train_arr[i, 0])

# %%
X_train, y_train = np.array(X_train), np.array(y_train)

# %% [markdown]
# ## 6.0 Building the Model

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2025-05-18 15:41:35.216133: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-18 15:41:35.219783: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-18 15:41:35.230525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747579295.248664  117755 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747579295.254012  117755 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747579295.267213  117755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747579295.267230  117755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747579295.267232  117755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747579295.267234  117755 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-18 15:41:35.271988: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.19.0

# %%
from keras.models import Sequential
from keras.layers import Input, LSTM, Dense

# %%
model = Sequential()
model.add(Input(shape=(seq_num, 1)))
model.add(LSTM(units=128, activation='tanh', return_sequences=True))
model.add(LSTM(units=64))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# 2025-05-18 15:41:36.903817: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ## 7.0 Train the Model

# %%
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0555
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 9.1556e-04
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 5.7902e-04
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.1769e-04
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 5.8982e-04
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 5.5201e-04
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.8957e-04
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 6.4331e-04
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.9103e-04
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 5.2741e-04
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.2775e-04
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.0891e-04
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 6.4190e-04
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 3.9268e-04
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 5.0795e-04
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.6511e-04
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.8648e-04
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 4.0037e-04
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 4.3778e-04
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - loss: 3.8261e-04
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - loss: 3.8842e-04
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 4.1151e-04
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.0168e-04
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.0524e-04
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.9878e-04
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.4660e-04
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.5258e-04
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 3.5997e-04
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.4309e-04
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 5.9422e-04
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.3649e-04
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 3.1341e-04
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 2.9918e-04
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 0.0016
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 3.7927e-04
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 0.0020
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.6896e-04
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 2.6942e-04
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.8027e-04
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 3.0719e-04
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 2.6476e-04
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 3.0016e-04
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 2.9796e-04
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 2.3649e-04
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 2.6206e-04
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 3.0527e-04
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 2.4367e-04
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 2.8243e-04
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 3.0381e-04
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 2.5501e-04

# %% [markdown]
# ## 8.0 Validate the model

# %%
data_val = df_val.Close
data_val_arr = scaler.transform(data_val)
X_val, y_val  = [], []
for i in range(seq_num, len(data_val_arr)):
    X_val.append(data_val_arr[i-100 : i])
    y_val.append(data_val_arr[i, 0])
X_val, y_val = np.array(X_val), np.array(y_val)

# %%
y_val_predict = model.predict(X_val)
y_val_predict = scaler.inverse_transform(y_val_predict).flatten()
y_val = scaler.inverse_transform(y_val.reshape(-1, 1)).flatten()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step

# %%
plt.figure(figsize = (12, 6))
plt.plot(y_val_predict, 'b', label='Val Prediction')
plt.plot(y_val, 'r', label= 'Val Data')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()

# %%
plt.figure(figsize = (12, 6))
plt.plot(y_val_predict, 'b', label='Val Prediction')
plt.plot(y_val, 'r', label= 'Val Data')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.xlim(0, 150)
plt.ylim(120, 200)
plt.legend()

# %% [markdown]
# ## 9.0 Model Evaluation

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_val, y_val_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_val, y_val_predict)
print("Mean Squared Error (MSE): ", mse)
print("Root Mean Squared Error (RMSE)", rmse)
print("R-Squared (R2): ", r2)
# Out:
# Mean Squared Error (MSE):  20.043959129081315
# Root Mean Squared Error (RMSE) 4.477048037388176
# R-Squared (R2):  0.9762368271450677

# %% [markdown]
# ## 10. Combining Training and Validation data to retrain the model

# %%
data_fulltrain = df_fulltrain.Close

# %%
data_fulltrain_arr = scaler.fit_transform(data_fulltrain)
X_fulltrain, y_fulltrain = [], []
for i in range(seq_num, len(data_fulltrain_arr)):
    X_fulltrain.append(data_fulltrain_arr[i-100 : i])
    y_fulltrain.append(data_fulltrain_arr[i, 0])
X_fulltrain, y_fulltrain = np.array(X_fulltrain), np.array(y_fulltrain)

# %%
model.fit(X_fulltrain, y_fulltrain, epochs=50)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 3.4626e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 3.5286e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 3.4812e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 3.5994e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 2.5513e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - loss: 2.8137e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - loss: 2.8164e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - loss: 2.4528e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 3.8019e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 2.4080e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 2.2816e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 2.0309e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.9306e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 2.3681e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 2.3376e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.6781e-04
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.5393e-04
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 2.3456e-04
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 2.4346e-04
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 2.2353e-04
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.7678e-04
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.6953e-04
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 2.2345e-04
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.4557e-04
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.3626e-04
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.3774e-04
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 1.9887e-04
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 2.2627e-04
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.5733e-04
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.6683e-04
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.1878e-04
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.3827e-04
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.2325e-04
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 3.3830e-04
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.8168e-04
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 2.5219e-04
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - loss: 2.1348e-04
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 2.3339e-04
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - loss: 2.2327e-04
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 2.4206e-04
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - loss: 2.1280e-04
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 2.2373e-04
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.9310e-04
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.5543e-04
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.3906e-04
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.1843e-04
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 3.1523e-04
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.3156e-04
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.7283e-04
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 2.9390e-04

# %% [markdown]
# ## 11.0 Testing the model

# %%
data_test = df_test.Close

# %%
data_test_arr = scaler.transform(data_test)
X_test, y_test = [], []
for i in range(seq_num, len(data_test_arr)):
    X_test.append(data_test_arr[i-100 : i])
    y_test.append(data_test_arr[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)

# %% [markdown]
# ### Prediction using test dataset

# %%
y_predict_test = model.predict(X_test)
y_predict_test = scaler.inverse_transform(y_predict_test).flatten()
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
plt.figure(figsize = (12, 6))
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.plot(y_test, 'r', label = 'Test Data')
plt.plot(y_predict_test, 'b', label = 'Predicted Test Data')
plt.legend()

# %% [markdown]
# ## 12.0 Evaluating the new model

# %%
mse = mean_squared_error(y_test, y_predict_test)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_predict_test)
print("Mean Squared Error (MSE): ", mse)
print("Root Mean Squared Error (RMSE)", rmse)
print("R-Squared (R2): ", r2)
# Out:
# Mean Squared Error (MSE):  14.885336397066737
# Root Mean Squared Error (RMSE) 3.858151940640329
# R-Squared (R2):  0.9780805297721615

# %% [markdown]
# ## 13.0 Saving the model

# %%
model.save('stock_prediction_model.keras')

# %%
joblib.dump(scaler, "stock_scaler.pkl")
# Out:
# ['stock_scaler.pkl']
